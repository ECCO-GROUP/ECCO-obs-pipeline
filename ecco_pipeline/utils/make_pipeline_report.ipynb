# %%
from pathlib import Path
import numpy as np
import yaml
import sys

# %%
pipeline_dir = Path('/home/ep/shared/ECCO-pipeline-ep/observations')
conf_dir = Path('/home/ep/shared/ECCO-pipeline-ep/ECCO-pipeline/ecco_pipeline/conf/ds_configs/')

# %%
datasets = np.sort(list(pipeline_dir.glob('*')))

# %%
datasets
# Out:
# array([PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/AMSR-2_OSI-408'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/AQUARIUS_L3_SSS_SMI_MONTHLY_V5'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/ATL20_V004_daily'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/ATL20_V004_monthly'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/AVHRR_OI-NCEI-L4-GLOB-v2.0'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/AVHRR_OI-NCEI-L4-GLOB-v2.1'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/G02202_V4'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/G10016_V2'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/GRC_FGO_GRIDDED_AOD1B_JPL_MASCON_RL06'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/L3_DEBIAS_LOCEAN_v8_q09'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/L3_DEBIAS_LOCEAN_v8_q18'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/MODIS_AQUA_L3_SST_THERMAL_DAILY_9KM_DAYTIME_V2019.0'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/OISSS_L4_multimission_monthly_v2'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/RDEFT4'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/SEA_SURFACE_HEIGHT_ALT_GRIDS_L4_2SATS_5DAY_6THDEG_V_JPL2205'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/SMAP_RSS_L3_SSS_SMI_MONTHLY_V4'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/SSMIS_OSI-401-b'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/SSMIS_OSI-430-a_daily'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/SSMIS_OSI-430-a_monthly'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/SSMIS_OSI-450-a_daily'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/SSMIS_OSI-450-a_monthly'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/TELLUS_GRAC-GRFO_MASCON_CRI_GRID_RL06.1_V3'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/TELLUS_GRAC-GRFO_MASCON_CRI_GRID_RL06_V2'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/TELLUS_GRAC_L3_CSR_RL06_OCN_v04'),
#        PosixPath('/home/ep/shared/ECCO-pipeline-ep/observations/TELLUS_GRFO_L3_CSR_RL06.2_OCN_v04')],
#       dtype=object)

# %%
yaml_exists = []
yaml_missing = []
yamls = dict()

yaml_missing = []
for ds in datasets:        
    try:
        with open(conf_dir / f'{ds.name}.yaml', 'r') as file:
          yamls[ds.name] = yaml.safe_load(file)
          yaml_exists.append(ds.name)
    except:
        yaml_missing.append(ds.name)

print(f'YAML LOADED: {len(yaml_exists)}')
print('------------')
for y in yaml_exists:
    print(f'  {y}')


print(f'\nYAML MISSING FOR DIRECTORIES: {len(yaml_missing)}')
print('-----------------------------')
for y in yaml_missing:
    print(f'  {y}')
# Out:
# YAML LOADED: 21
# ------------
#   AMSR-2_OSI-408
#   AQUARIUS_L3_SSS_SMI_MONTHLY_V5
#   ATL20_V004_daily
#   ATL20_V004_monthly
#   AVHRR_OI-NCEI-L4-GLOB-v2.0
#   AVHRR_OI-NCEI-L4-GLOB-v2.1
#   G02202_V4
#   G10016_V2
#   L3_DEBIAS_LOCEAN_v8_q09
#   L3_DEBIAS_LOCEAN_v8_q18
#   MODIS_AQUA_L3_SST_THERMAL_DAILY_9KM_DAYTIME_V2019.0
#   OISSS_L4_multimission_monthly_v2
#   RDEFT4
#   SEA_SURFACE_HEIGHT_ALT_GRIDS_L4_2SATS_5DAY_6THDEG_V_JPL2205
#   SMAP_RSS_L3_SSS_SMI_MONTHLY_V4
#   SSMIS_OSI-430-a_daily
#   SSMIS_OSI-430-a_monthly
#   SSMIS_OSI-450-a_daily
#   SSMIS_OSI-450-a_monthly
#   TELLUS_GRAC-GRFO_MASCON_CRI_GRID_RL06.1_V3
#   TELLUS_GRFO_L3_CSR_RL06.2_OCN_v04
#
# YAML MISSING FOR DIRECTORIES: 4
# -----------------------------
#   GRC_FGO_GRIDDED_AOD1B_JPL_MASCON_RL06
#   SSMIS_OSI-401-b
#   TELLUS_GRAC-GRFO_MASCON_CRI_GRID_RL06_V2
#   TELLUS_GRAC_L3_CSR_RL06_OCN_v04

# %%
ds_found = dict()

for ds in datasets:
    print('\n')
    print(ds)
    ds_found[ds.name] = dict()
    grids = list((ds / 'transformed_products').glob('*'))
    
    for g in grids:
        ds_found[ds.name][g.name] = dict()
        
        print(f'   {g.name}')
        vars= list((ds / 'transformed_products' / g/ 'aggregated').glob('*'))

        for var in vars:
            ds_found[ds.name][g.name][var.name] = dict()
            print(f'      {var.name}')
            fp = Path(ds / 'transformed_products' / g/ 'aggregated' / var / 'netCDF')
            mon_files =  list(fp.glob(f'*{g.name}_MONTHLY*nc'))
            day_files =  list(fp.glob(f'*{g.name}_DAILY*nc'))

            if len(mon_files) > 0:
                mon_fns = [file.name for file in mon_files]
            else:
                mon_fns = []

            if len(day_files) > 0:
                day_fns = [file.name for file in day_files]            
            else:
               day_fns = []

            ds_found[ds.name][g.name][var.name]['file_path']  = fp
            ds_found[ds.name][g.name][var.name]['mon_files']  = mon_fns
            ds_found[ds.name][g.name][var.name]['day_files']  = day_fns


            #ds_found[ds.name][g.name][var.name] = fncs
# Out:
# /home/ep/shared/ECCO-pipeline-ep/observations/AMSR-2_OSI-408
#    ECCO_llc90
#       ice_conc
#       confidence_level
#       total_uncertainty
#    ECCO_llc270
#       ice_conc
#       confidence_level
#       total_uncertainty
#    TPOSE
#       ice_conc
#       confidence_level
#       total_uncertainty
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/AQUARIUS_L3_SSS_SMI_MONTHLY_V5
#    ECCO_llc90
#       SSS
#       SSS_sys_unc
#    ECCO_llc270
#       SSS
#       SSS_sys_unc
#    TPOSE
#       SSS
#       SSS_sys_unc
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/ATL20_V004_daily
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/ATL20_V004_monthly
#    ECCO_llc90
#       mean_fb
#    ECCO_llc270
#       mean_fb
#    TPOSE
#       mean_fb
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/AVHRR_OI-NCEI-L4-GLOB-v2.0
#    ECCO_llc90
#       analysed_sst
#       analysis_error
#    ECCO_llc270
#    TPOSE
#       analysed_sst
#       analysis_error
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/AVHRR_OI-NCEI-L4-GLOB-v2.1
#    ECCO_llc90
#       analysed_sst
#       analysis_error
#    ECCO_llc270
#       analysed_sst
#       analysis_error
#    TPOSE
#       analysed_sst
#       analysis_error
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/G02202_V4
#    ECCO_llc90
#       cdr_seaice_conc
#       stdev_of_cdr_seaice_conc
#       nsidc_nt_seaice_conc
#    ECCO_llc270
#       cdr_seaice_conc
#       stdev_of_cdr_seaice_conc
#       nsidc_nt_seaice_conc
#    TPOSE
#       cdr_seaice_conc
#       stdev_of_cdr_seaice_conc
#       nsidc_nt_seaice_conc
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/G10016_V2
#    ECCO_llc90
#       cdr_seaice_conc
#       stdev_of_cdr_seaice_conc
#    ECCO_llc270
#       cdr_seaice_conc
#       stdev_of_cdr_seaice_conc
#    TPOSE
#       cdr_seaice_conc
#       stdev_of_cdr_seaice_conc
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/GRC_FGO_GRIDDED_AOD1B_JPL_MASCON_RL06
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/L3_DEBIAS_LOCEAN_v8_q09
#    ECCO_llc90
#       SSS
#       eSSS
#    ECCO_llc270
#       SSS
#       eSSS
#    TPOSE
#       SSS
#       eSSS
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/L3_DEBIAS_LOCEAN_v8_q18
#    ECCO_llc90
#       SSS
#       eSSS
#    ECCO_llc270
#       SSS
#       eSSS
#    TPOSE
#       SSS
#       eSSS
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/MODIS_AQUA_L3_SST_THERMAL_DAILY_9KM_DAYTIME_V2019.0
#    ECCO_llc90
#       sst
#    ECCO_llc270
#       sst
#    TPOSE
#       sst
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/OISSS_L4_multimission_monthly_v2
#    ECCO_llc90
#       sss
#       sss_empirical_uncertainty
#    ECCO_llc270
#       sss
#       sss_empirical_uncertainty
#    TPOSE
#       sss
#       sss_empirical_uncertainty
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/RDEFT4
#    ECCO_llc90
#       sea_ice_thickness
#       snow_depth
#       freeboard
#    ECCO_llc270
#       sea_ice_thickness
#       snow_depth
#       freeboard
#    TPOSE
#       sea_ice_thickness
#       snow_depth
#       freeboard
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/SEA_SURFACE_HEIGHT_ALT_GRIDS_L4_2SATS_5DAY_6THDEG_V_JPL2205
#    ECCO_llc90
#       SLA
#       SLA_ERR
#    ECCO_llc270
#       SLA
#       SLA_ERR
#    TPOSE
#       SLA
#       SLA_ERR
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/SMAP_RSS_L3_SSS_SMI_MONTHLY_V4
#    ECCO_llc90
#       sss_smap_40km
#       sss_smap_uncertainty
#    ECCO_llc270
#       sss_smap_40km
#       sss_smap_uncertainty
#    TPOSE
#       sss_smap_40km
#       sss_smap_uncertainty
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/SSMIS_OSI-401-b
#    ECCO_llc90
#       ice_conc
#       confidence_level
#    ECCO_llc270
#       ice_conc
#       confidence_level
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/SSMIS_OSI-430-a_daily
#    ECCO_llc90
#       ice_conc
#       total_standard_uncertainty
#    ECCO_llc270
#       ice_conc
#       total_standard_uncertainty
#    TPOSE
#       ice_conc
#       total_standard_uncertainty
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/SSMIS_OSI-430-a_monthly
#    ECCO_llc90
#       ice_conc
#    ECCO_llc270
#       ice_conc
#    TPOSE
#       ice_conc
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/SSMIS_OSI-450-a_daily
#    ECCO_llc90
#       ice_conc
#       total_standard_uncertainty
#    ECCO_llc270
#       ice_conc
#       total_standard_uncertainty
#    TPOSE
#       ice_conc
#       total_standard_uncertainty
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/SSMIS_OSI-450-a_monthly
#    ECCO_llc90
#       ice_conc
#    ECCO_llc270
#       ice_conc
#    TPOSE
#       ice_conc
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/TELLUS_GRAC-GRFO_MASCON_CRI_GRID_RL06.1_V3
#    ECCO_llc90
#       lwe_thickness
#       uncertainty
#    ECCO_llc270
#       lwe_thickness
#       uncertainty
#    TPOSE
#       lwe_thickness
#       uncertainty
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/TELLUS_GRAC-GRFO_MASCON_CRI_GRID_RL06_V2
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/TELLUS_GRAC_L3_CSR_RL06_OCN_v04
#    ECCO_llc90
#       lwe_thickness
#       uncertainty
#    ECCO_llc270
#       lwe_thickness
#       uncertainty
#    TPOSE
#       lwe_thickness
#       uncertainty
#
#
# /home/ep/shared/ECCO-pipeline-ep/observations/TELLUS_GRFO_L3_CSR_RL06.2_OCN_v04
#    ECCO_llc90
#       lwe_thickness
#       uncertainty
#    ECCO_llc270
#       lwe_thickness
#       uncertainty
#    TPOSE
#       lwe_thickness
#       uncertainty

# %%
def export_ds_found_dict(ds_found, export_filename=''):

    tmp_stdout= sys.stdout

    if len(export_filename) > 0:
        try:
            sys.stdout = open(export_filename,'wt')
        except:
            print('could not make filename')
            return ''
            
    
    print(f'Datasets in {pipeline_dir}')
    print('===================================================')
    for ds in ds_found.keys():
        print(f'{ds}')
    
    for ds in ds_found.keys():
        print('\n===============================================================')
        if ds in yamls:
            print(f"{ds}\n{yamls[ds]['original_dataset_title']}")
            print(f"doi:{yamls[ds]['original_dataset_doi']}")
        else:
            print(f'{ds}\nYAML not founds in ds_conf')
    
        print(  '===============================================================')
        if len(ds_found[ds].keys()) == 0:
            print ('\nNO DATA!\n')
        
        for g in ds_found[ds].keys():
            print(f'\n  =>> {g} <<= ')
    
            for v in ds_found[ds][g].keys():
                tmp = ds_found[ds][g][v];
    
                t2 = len(tmp['mon_files'])
                if t2  > 0:
                    mfy = tmp['mon_files'][0][-7:-3]
                    mly = tmp['mon_files'][-1][-7:-3]
                    mflys = f'[{mfy}-{mly}]'
                else:
                    mflys = ''
                    
                t3 = len(tmp['day_files'])
                if t3 > 0:
                    dfy = tmp['day_files'][0][-7:-3]
                    dly = tmp['day_files'][-1][-7:-3]
                    dflys = f'[{dfy}-{dly}]'
                else:
                    dflys = ''
                    
                print(f"     * {v.ljust(28)}   MON:{str(len(tmp['mon_files'])).ljust(2)} {mflys}  DAY:{str(len(tmp['day_files'])).ljust(2)} {dflys}")

    sys.stdout = tmp_stdout

# %%
export_ds_found_dict(ds_found, export_filename='/home/ifenty/test.txt')

# %%
export_ds_found_dict(ds_found)
# Out:
# Datasets in /home/ep/shared/ECCO-pipeline-ep/observations
# ===================================================
# AMSR-2_OSI-408
# AQUARIUS_L3_SSS_SMI_MONTHLY_V5
# ATL20_V004_daily
# ATL20_V004_monthly
# AVHRR_OI-NCEI-L4-GLOB-v2.0
# AVHRR_OI-NCEI-L4-GLOB-v2.1
# G02202_V4
# G10016_V2
# GRC_FGO_GRIDDED_AOD1B_JPL_MASCON_RL06
# L3_DEBIAS_LOCEAN_v8_q09
# L3_DEBIAS_LOCEAN_v8_q18
# MODIS_AQUA_L3_SST_THERMAL_DAILY_9KM_DAYTIME_V2019.0
# OISSS_L4_multimission_monthly_v2
# RDEFT4
# SEA_SURFACE_HEIGHT_ALT_GRIDS_L4_2SATS_5DAY_6THDEG_V_JPL2205
# SMAP_RSS_L3_SSS_SMI_MONTHLY_V4
# SSMIS_OSI-401-b
# SSMIS_OSI-430-a_daily
# SSMIS_OSI-430-a_monthly
# SSMIS_OSI-450-a_daily
# SSMIS_OSI-450-a_monthly
# TELLUS_GRAC-GRFO_MASCON_CRI_GRID_RL06.1_V3
# TELLUS_GRAC-GRFO_MASCON_CRI_GRID_RL06_V2
# TELLUS_GRAC_L3_CSR_RL06_OCN_v04
# TELLUS_GRFO_L3_CSR_RL06.2_OCN_v04
#
# ===============================================================
# AMSR-2_OSI-408
# Global Sea Ice Concentration (AMSR-2)
# doi:OSI-408
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * ice_conc                       MON:8  [2016-2023]  DAY:8  [2016-2023]
#      * confidence_level               MON:8  [2016-2023]  DAY:8  [2016-2023]
#      * total_uncertainty              MON:8  [2016-2023]  DAY:8  [2016-2023]
#
#   =>> ECCO_llc270 <<=
#      * ice_conc                       MON:8  [2016-2023]  DAY:8  [2016-2023]
#      * confidence_level               MON:8  [2016-2023]  DAY:8  [2016-2023]
#      * total_uncertainty              MON:8  [2016-2023]  DAY:8  [2016-2023]
#
#   =>> TPOSE <<=
#      * ice_conc                       MON:0    DAY:0
#      * confidence_level               MON:0    DAY:0
#      * total_uncertainty              MON:0    DAY:0
#
# ===============================================================
# AQUARIUS_L3_SSS_SMI_MONTHLY_V5
# Aquarius Official Release Level 3 Sea Surface Salinity Standard Mapped Image Monthly Data V5.0
# doi:10.5067/AQR50-3SMCS
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * SSS                            MON:5  [2011-2015]  DAY:0
#      * SSS_sys_unc                    MON:5  [2011-2015]  DAY:0
#
#   =>> ECCO_llc270 <<=
#      * SSS                            MON:5  [2011-2015]  DAY:0
#      * SSS_sys_unc                    MON:5  [2011-2015]  DAY:0
#
#   =>> TPOSE <<=
#      * SSS                            MON:5  [2011-2015]  DAY:0
#      * SSS_sys_unc                    MON:5  [2011-2015]  DAY:0
#
# ===============================================================
# ATL20_V004_daily
# ATLAS/ICESat-2 L3B Daily and Monthly Gridded Sea Ice Freeboard, Version 4 (ATL20)
# doi:10.5067/ATLAS/ATL20.004
# ===============================================================
#
# NO DATA!
#
#
# ===============================================================
# ATL20_V004_monthly
# ATLAS/ICESat-2 L3B Daily and Monthly Gridded Sea Ice Freeboard, Version 4 (ATL20)
# doi:10.5067/ATLAS/ATL20.004
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * mean_fb                        MON:6  [2018-2023]  DAY:0
#
#   =>> ECCO_llc270 <<=
#      * mean_fb                        MON:6  [2018-2023]  DAY:0
#
#   =>> TPOSE <<=
#      * mean_fb                        MON:0    DAY:0
#
# ===============================================================
# AVHRR_OI-NCEI-L4-GLOB-v2.0
# GHRSST Level 4 AVHRR_OI Global Blended Sea Surface Temperature Analysis (GDS version 2) from NCEI
# doi:10.5067/GHAAO-4BC02
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * analysed_sst                   MON:35 [1981-2015]  DAY:35 [1981-2015]
#      * analysis_error                 MON:35 [1981-2015]  DAY:35 [1981-2015]
#
#   =>> ECCO_llc270 <<=
#
#   =>> TPOSE <<=
#      * analysed_sst                   MON:16 [1981-1996]  DAY:16 [1981-1996]
#      * analysis_error                 MON:16 [1981-1996]  DAY:16 [1981-1996]
#
# ===============================================================
# AVHRR_OI-NCEI-L4-GLOB-v2.1
# GHRSST Level 4 AVHRR_OI Global Blended Sea Surface Temperature Analysis (GDS2) from NCEI
# doi:10.5067/GHAAO-4BC21
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * analysed_sst                   MON:8  [2016-2023]  DAY:8  [2016-2023]
#      * analysis_error                 MON:8  [2016-2023]  DAY:8  [2016-2023]
#
#   =>> ECCO_llc270 <<=
#      * analysed_sst                   MON:8  [2016-2023]  DAY:8  [2016-2023]
#      * analysis_error                 MON:8  [2016-2023]  DAY:8  [2016-2023]
#
#   =>> TPOSE <<=
#      * analysed_sst                   MON:8  [2016-2023]  DAY:8  [2016-2023]
#      * analysis_error                 MON:8  [2016-2023]  DAY:8  [2016-2023]
#
# ===============================================================
# G02202_V4
# NOAA/NSIDC Climate Data Record of Passive Microwave Sea Ice Concentration, Version 4
# doi:10.7265/efmz-2t65
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * cdr_seaice_conc                MON:44 [1980-2023]  DAY:44 [1980-2023]
#      * stdev_of_cdr_seaice_conc       MON:44 [1980-2023]  DAY:44 [1980-2023]
#      * nsidc_nt_seaice_conc           MON:44 [1980-2023]  DAY:44 [1980-2023]
#
#   =>> ECCO_llc270 <<=
#      * cdr_seaice_conc                MON:44 [1980-2023]  DAY:44 [1980-2023]
#      * stdev_of_cdr_seaice_conc       MON:44 [1980-2023]  DAY:44 [1980-2023]
#      * nsidc_nt_seaice_conc           MON:44 [1980-2023]  DAY:44 [1980-2023]
#
#   =>> TPOSE <<=
#      * cdr_seaice_conc                MON:0    DAY:0
#      * stdev_of_cdr_seaice_conc       MON:0    DAY:0
#      * nsidc_nt_seaice_conc           MON:0    DAY:0
#
# ===============================================================
# G10016_V2
# Near-Real-Time NOAA/NSIDC Climate Data Record of Passive Microwave Sea Ice Concentration, Version 1
# doi:10.7265/tgam-yv28
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * cdr_seaice_conc                MON:2  [2022-2023]  DAY:2  [2022-2023]
#      * stdev_of_cdr_seaice_conc       MON:2  [2022-2023]  DAY:2  [2022-2023]
#
#   =>> ECCO_llc270 <<=
#      * cdr_seaice_conc                MON:2  [2022-2023]  DAY:2  [2022-2023]
#      * stdev_of_cdr_seaice_conc       MON:2  [2022-2023]  DAY:2  [2022-2023]
#
#   =>> TPOSE <<=
#      * cdr_seaice_conc                MON:0    DAY:0
#      * stdev_of_cdr_seaice_conc       MON:0    DAY:0
#
# ===============================================================
# GRC_FGO_GRIDDED_AOD1B_JPL_MASCON_RL06
# YAML not founds in ds_conf
# ===============================================================
#
# NO DATA!
#
#
# ===============================================================
# L3_DEBIAS_LOCEAN_v8_q09
# SMOS SSS L3 maps generated by CATDS CEC LOCEAN. debias V8.0
# doi:10.17882/52804
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * SSS                            MON:13 [2010-2022]  DAY:13 [2010-2022]
#      * eSSS                           MON:13 [2010-2022]  DAY:13 [2010-2022]
#
#   =>> ECCO_llc270 <<=
#      * SSS                            MON:13 [2010-2022]  DAY:13 [2010-2022]
#      * eSSS                           MON:13 [2010-2022]  DAY:13 [2010-2022]
#
#   =>> TPOSE <<=
#      * SSS                            MON:13 [2010-2022]  DAY:13 [2010-2022]
#      * eSSS                           MON:13 [2010-2022]  DAY:13 [2010-2022]
#
# ===============================================================
# L3_DEBIAS_LOCEAN_v8_q18
# SMOS SSS L3 maps generated by CATDS CEC LOCEAN. debias V8.0
# doi:10.17882/52804
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * SSS                            MON:13 [2010-2022]  DAY:13 [2010-2022]
#      * eSSS                           MON:13 [2010-2022]  DAY:13 [2010-2022]
#
#   =>> ECCO_llc270 <<=
#      * SSS                            MON:13 [2010-2022]  DAY:13 [2010-2022]
#      * eSSS                           MON:13 [2010-2022]  DAY:13 [2010-2022]
#
#   =>> TPOSE <<=
#      * SSS                            MON:13 [2010-2022]  DAY:13 [2010-2022]
#      * eSSS                           MON:13 [2010-2022]  DAY:13 [2010-2022]
#
# ===============================================================
# MODIS_AQUA_L3_SST_THERMAL_DAILY_9KM_DAYTIME_V2019.0
# MODIS Aqua Level 3 SST Thermal IR Daily 9km Daytime V2019.0
# doi:10.5067/MODSA-1D9D9
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * sst                            MON:22 [2002-2023]  DAY:22 [2002-2023]
#
#   =>> ECCO_llc270 <<=
#      * sst                            MON:22 [2002-2023]  DAY:22 [2002-2023]
#
#   =>> TPOSE <<=
#      * sst                            MON:22 [2002-2023]  DAY:22 [2002-2023]
#
# ===============================================================
# OISSS_L4_multimission_monthly_v2
# Multi-Mission Optimally Interpolated Sea Surface Salinity Global Monthly Dataset V2
# doi:10.1002/2015JC011343
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * sss                            MON:13 [2011-2023]  DAY:0
#      * sss_empirical_uncertainty      MON:13 [2011-2023]  DAY:0
#
#   =>> ECCO_llc270 <<=
#      * sss                            MON:13 [2011-2023]  DAY:0
#      * sss_empirical_uncertainty      MON:13 [2011-2023]  DAY:0
#
#   =>> TPOSE <<=
#      * sss                            MON:13 [2011-2023]  DAY:0
#      * sss_empirical_uncertainty      MON:13 [2011-2023]  DAY:0
#
# ===============================================================
# RDEFT4
# CryoSat-2 Level-4 Sea Ice Elevation, Freeboard, and Thickness, Version 1
# doi:10.5067/96JO0KIFDAS8
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * sea_ice_thickness              MON:14 [2010-2023]  DAY:0
#      * snow_depth                     MON:14 [2010-2023]  DAY:0
#      * freeboard                      MON:14 [2010-2023]  DAY:0
#
#   =>> ECCO_llc270 <<=
#      * sea_ice_thickness              MON:14 [2010-2023]  DAY:0
#      * snow_depth                     MON:14 [2010-2023]  DAY:0
#      * freeboard                      MON:14 [2010-2023]  DAY:0
#
#   =>> TPOSE <<=
#      * sea_ice_thickness              MON:0    DAY:0
#      * snow_depth                     MON:0    DAY:0
#      * freeboard                      MON:0    DAY:0
#
# ===============================================================
# SEA_SURFACE_HEIGHT_ALT_GRIDS_L4_2SATS_5DAY_6THDEG_V_JPL2205
# MEaSUREs Gridded Sea Surface Height Anomalies Version 2205
# doi:10.5067/SLREF-CDRV3
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * SLA                            MON:31 [1992-2022]  DAY:31 [1992-2022]
#      * SLA_ERR                        MON:31 [1992-2022]  DAY:31 [1992-2022]
#
#   =>> ECCO_llc270 <<=
#      * SLA                            MON:31 [1992-2022]  DAY:31 [1992-2022]
#      * SLA_ERR                        MON:31 [1992-2022]  DAY:31 [1992-2022]
#
#   =>> TPOSE <<=
#      * SLA                            MON:31 [1992-2022]  DAY:31 [1992-2022]
#      * SLA_ERR                        MON:31 [1992-2022]  DAY:31 [1992-2022]
#
# ===============================================================
# SMAP_RSS_L3_SSS_SMI_MONTHLY_V4
# RSS SMAP Level 3 Sea Surface Salinity Standard Mapped Image Monthly V4.0 Validated Dataset
# doi:10.5067/SMP40-3SMCS
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * sss_smap_40km                  MON:8  [2015-2022]  DAY:0
#      * sss_smap_uncertainty           MON:8  [2015-2022]  DAY:0
#
#   =>> ECCO_llc270 <<=
#      * sss_smap_40km                  MON:8  [2015-2022]  DAY:0
#      * sss_smap_uncertainty           MON:8  [2015-2022]  DAY:0
#
#   =>> TPOSE <<=
#      * sss_smap_40km                  MON:8  [2015-2022]  DAY:0
#      * sss_smap_uncertainty           MON:8  [2015-2022]  DAY:0
#
# ===============================================================
# SSMIS_OSI-401-b
# YAML not founds in ds_conf
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * ice_conc                       MON:19 [2005-2023]  DAY:19 [2005-2023]
#      * confidence_level               MON:19 [2005-2023]  DAY:19 [2005-2023]
#
#   =>> ECCO_llc270 <<=
#      * ice_conc                       MON:19 [2005-2023]  DAY:19 [2005-2023]
#      * confidence_level               MON:19 [2005-2023]  DAY:19 [2005-2023]
#
# ===============================================================
# SSMIS_OSI-430-a_daily
# Global Sea Ice Concentration interim climate data record (SSMIS)
# doi:10.15770/EUM_SAF_OSI_0014
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * ice_conc                       MON:3  [2021-2023]  DAY:3  [2021-2023]
#      * total_standard_uncertainty     MON:3  [2021-2023]  DAY:3  [2021-2023]
#
#   =>> ECCO_llc270 <<=
#      * ice_conc                       MON:3  [2021-2023]  DAY:3  [2021-2023]
#      * total_standard_uncertainty     MON:3  [2021-2023]  DAY:3  [2021-2023]
#
#   =>> TPOSE <<=
#      * ice_conc                       MON:3  [2021-2023]  DAY:3  [2021-2023]
#      * total_standard_uncertainty     MON:3  [2021-2023]  DAY:3  [2021-2023]
#
# ===============================================================
# SSMIS_OSI-430-a_monthly
# Global Sea Ice Concentration interim climate data record (SSMIS)
# doi:10.15770/EUM_SAF_OSI_0014
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * ice_conc                       MON:3  [2021-2023]  DAY:0
#
#   =>> ECCO_llc270 <<=
#      * ice_conc                       MON:3  [2021-2023]  DAY:0
#
#   =>> TPOSE <<=
#      * ice_conc                       MON:3  [2021-2023]  DAY:0
#
# ===============================================================
# SSMIS_OSI-450-a_daily
# Global Sea Ice Concentration interim climate data record (SSMIS)
# doi:10.15770/EUM_SAF_OSI_0014
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * ice_conc                       MON:41 [1980-2020]  DAY:41 [1980-2020]
#      * total_standard_uncertainty     MON:41 [1980-2020]  DAY:41 [1980-2020]
#
#   =>> ECCO_llc270 <<=
#      * ice_conc                       MON:41 [1980-2020]  DAY:41 [1980-2020]
#      * total_standard_uncertainty     MON:41 [1980-2020]  DAY:41 [1980-2020]
#
#   =>> TPOSE <<=
#      * ice_conc                       MON:41 [1980-2020]  DAY:41 [1980-2020]
#      * total_standard_uncertainty     MON:41 [1980-2020]  DAY:41 [1980-2020]
#
# ===============================================================
# SSMIS_OSI-450-a_monthly
# Global Sea Ice Concentration interim climate data record (SSMIS)
# doi:10.15770/EUM_SAF_OSI_0014
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * ice_conc                       MON:41 [1980-2020]  DAY:0
#
#   =>> ECCO_llc270 <<=
#      * ice_conc                       MON:41 [1980-2020]  DAY:0
#
#   =>> TPOSE <<=
#      * ice_conc                       MON:41 [1980-2020]  DAY:0
#
# ===============================================================
# TELLUS_GRAC-GRFO_MASCON_CRI_GRID_RL06.1_V3
# JPL GRACE and GRACE-FO Mascon Ocean, Ice, and Hydrology Equivalent Water Height Coastal Resolution Improvement (CRI) Filtered Release 06 Version 03
# doi:10.5067/TEMSC-3JC63
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * lwe_thickness                  MON:1  [2002-2002]  DAY:0
#      * uncertainty                    MON:1  [2002-2002]  DAY:0
#
#   =>> ECCO_llc270 <<=
#      * lwe_thickness                  MON:1  [2002-2002]  DAY:0
#      * uncertainty                    MON:1  [2002-2002]  DAY:0
#
#   =>> TPOSE <<=
#      * lwe_thickness                  MON:1  [2002-2002]  DAY:0
#      * uncertainty                    MON:1  [2002-2002]  DAY:0
#
# ===============================================================
# TELLUS_GRAC-GRFO_MASCON_CRI_GRID_RL06_V2
# YAML not founds in ds_conf
# ===============================================================
#
# NO DATA!
#
#
# ===============================================================
# TELLUS_GRAC_L3_CSR_RL06_OCN_v04
# YAML not founds in ds_conf
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * lwe_thickness                  MON:16 [2002-2017]  DAY:0
#      * uncertainty                    MON:16 [2002-2017]  DAY:0
#
#   =>> ECCO_llc270 <<=
#      * lwe_thickness                  MON:16 [2002-2017]  DAY:0
#      * uncertainty                    MON:16 [2002-2017]  DAY:0
#
#   =>> TPOSE <<=
#      * lwe_thickness                  MON:16 [2002-2017]  DAY:0
#      * uncertainty                    MON:16 [2002-2017]  DAY:0
#
# ===============================================================
# TELLUS_GRFO_L3_CSR_RL06.2_OCN_v04
# CSR TELLUS GRACE-FO Level-3 Monthly Ocean Bottom Pressure Anomaly Release 6.2 version 04
# doi:10.1029/2011WR011453
# ===============================================================
#
#   =>> ECCO_llc90 <<=
#      * lwe_thickness                  MON:6  [2018-2023]  DAY:0
#      * uncertainty                    MON:6  [2018-2023]  DAY:0
#
#   =>> ECCO_llc270 <<=
#      * lwe_thickness                  MON:6  [2018-2023]  DAY:0
#      * uncertainty                    MON:6  [2018-2023]  DAY:0
#
#   =>> TPOSE <<=
#      * lwe_thickness                  MON:6  [2018-2023]  DAY:0
#      * uncertainty                    MON:6  [2018-2023]  DAY:0
